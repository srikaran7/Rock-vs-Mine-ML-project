# %% [markdown]
# importing the libraries

# %%
# !pip install -U scikit-learn

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# Data collection and Data processing

# %%
# loading the data set to pandas dataframe
sonar_data = pd.read_csv('/content/sample_data/Copy of sonar data.csv',header = 0)

# %%
sonar_data.head()
# Out:
#    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  ...  0.0167  0.0180  0.0084  0.0090  0.0032  R
# 0  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  ...  0.0191  0.0140  0.0049  0.0052  0.0044  R
# 1  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  ...  0.0244  0.0316  0.0164  0.0095  0.0078  R
# 2  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  ...  0.0073  0.0050  0.0044  0.0040  0.0117  R
# 3  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  ...  0.0015  0.0072  0.0048  0.0107  0.0094  R
# 4  0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  ...  0.0089  0.0057  0.0027  0.0051  0.0062  R
#
# [5 rows x 61 columns]

# %%
sonar_data.shape
# Out:
# (207, 61)

# %%
sonar_data.describe()  # decribe gives the statistical measures of the data
# Out:
#            0.0200      0.0371      0.0428  ...      0.0084      0.0090      0.0032
# count  207.000000  207.000000  207.000000  ...  207.000000  207.000000  207.000000
# mean     0.029208    0.038443    0.043837  ...    0.007947    0.007936    0.006523
# std      0.023038    0.033040    0.038521  ...    0.006485    0.006196    0.005038
# min      0.001500    0.000600    0.001500  ...    0.000300    0.000100    0.000600
# 25%      0.013300    0.016400    0.018900  ...    0.003600    0.003650    0.003100
# 50%      0.022800    0.030800    0.034200  ...    0.005800    0.006300    0.005300
# 75%      0.035800    0.048100    0.058200  ...    0.010400    0.010350    0.008550
# max      0.137100    0.233900    0.305900  ...    0.044000    0.036400    0.043900
#
# [8 rows x 60 columns]

# %%
print(sonar_data.columns)
# Out:
# Index(['0.0200', '0.0371', '0.0428', '0.0207', '0.0954', '0.0986', '0.1539',
#        '0.1601', '0.3109', '0.2111', '0.1609', '0.1582', '0.2238', '0.0645',
#        '0.0660', '0.2273', '0.3100', '0.2999', '0.5078', '0.4797', '0.5783',
#        '0.5071', '0.4328', '0.5550', '0.6711', '0.6415', '0.7104', '0.8080',
#        '0.6791', '0.3857', '0.1307', '0.2604', '0.5121', '0.7547', '0.8537',
#        '0.8507', '0.6692', '0.6097', '0.4943', '0.2744', '0.0510', '0.2834',
#        '0.2825', '0.4256', '0.2641', '0.1386', '0.1051', '0.1343', '0.0383',
#        '0.0324', '0.0232', '0.0027', '0.0065', '0.0159', '0.0072', '0.0167',
#        '0.0180', '0.0084', '0.0090', '0.0032', 'R'],
#       dtype='object')

# %%
sonar_data.iloc[:, 60].value_counts()
# Out:
# R
# M    111
# R     96
# Name: count, dtype: int64

# %% [markdown]
# M - > mine
# R -> Rock

# %%
print(sonar_data.columns)
# Out:
# Index(['0.0200', '0.0371', '0.0428', '0.0207', '0.0954', '0.0986', '0.1539',
#        '0.1601', '0.3109', '0.2111', '0.1609', '0.1582', '0.2238', '0.0645',
#        '0.0660', '0.2273', '0.3100', '0.2999', '0.5078', '0.4797', '0.5783',
#        '0.5071', '0.4328', '0.5550', '0.6711', '0.6415', '0.7104', '0.8080',
#        '0.6791', '0.3857', '0.1307', '0.2604', '0.5121', '0.7547', '0.8537',
#        '0.8507', '0.6692', '0.6097', '0.4943', '0.2744', '0.0510', '0.2834',
#        '0.2825', '0.4256', '0.2641', '0.1386', '0.1051', '0.1343', '0.0383',
#        '0.0324', '0.0232', '0.0027', '0.0065', '0.0159', '0.0072', '0.0167',
#        '0.0180', '0.0084', '0.0090', '0.0032', 'R'],
#       dtype='object')

# %%
print(sonar_data.columns)
# Out:
# Index(['0.0200', '0.0371', '0.0428', '0.0207', '0.0954', '0.0986', '0.1539',
#        '0.1601', '0.3109', '0.2111', '0.1609', '0.1582', '0.2238', '0.0645',
#        '0.0660', '0.2273', '0.3100', '0.2999', '0.5078', '0.4797', '0.5783',
#        '0.5071', '0.4328', '0.5550', '0.6711', '0.6415', '0.7104', '0.8080',
#        '0.6791', '0.3857', '0.1307', '0.2604', '0.5121', '0.7547', '0.8537',
#        '0.8507', '0.6692', '0.6097', '0.4943', '0.2744', '0.0510', '0.2834',
#        '0.2825', '0.4256', '0.2641', '0.1386', '0.1051', '0.1343', '0.0383',
#        '0.0324', '0.0232', '0.0027', '0.0065', '0.0159', '0.0072', '0.0167',
#        '0.0180', '0.0084', '0.0090', '0.0032', 'R'],
#       dtype='object')

# %%
for i, col in enumerate(sonar_data.columns):
    print(f"col {i}: {col}")
# Out:
# col 0: 0.0200
# col 1: 0.0371
# col 2: 0.0428
# col 3: 0.0207
# col 4: 0.0954
# col 5: 0.0986
# col 6: 0.1539
# col 7: 0.1601
# col 8: 0.3109
# col 9: 0.2111
# col 10: 0.1609
# col 11: 0.1582
# col 12: 0.2238
# col 13: 0.0645
# col 14: 0.0660
# col 15: 0.2273
# col 16: 0.3100
# col 17: 0.2999
# col 18: 0.5078
# col 19: 0.4797
# col 20: 0.5783
# col 21: 0.5071
# col 22: 0.4328
# col 23: 0.5550
# col 24: 0.6711
# col 25: 0.6415
# col 26: 0.7104
# col 27: 0.8080
# col 28: 0.6791
# col 29: 0.3857
# col 30: 0.1307
# col 31: 0.2604
# col 32: 0.5121
# col 33: 0.7547
# col 34: 0.8537
# col 35: 0.8507
# col 36: 0.6692
# col 37: 0.6097
# col 38: 0.4943
# col 39: 0.2744
# col 40: 0.0510
# col 41: 0.2834
# col 42: 0.2825
# col 43: 0.4256
# col 44: 0.2641
# col 45: 0.1386
# col 46: 0.1051
# col 47: 0.1343
# col 48: 0.0383
# col 49: 0.0324
# col 50: 0.0232
# col 51: 0.0027
# col 52: 0.0065
# col 53: 0.0159
# col 54: 0.0072
# col 55: 0.0167
# col 56: 0.0180
# col 57: 0.0084
# col 58: 0.0090
# ...

# %%
means = sonar_data.mean(numeric_only=True)  # Compute mean for numeric columns

print("Column Index | Column Name | Mean Value")
print("--------------------------------------")

for i, (col, mean_value) in enumerate(means.items()):

    print(f"{i:<12} | {col:<11} | {mean_value:.4f}")
# Out:
# Column Index | Column Name | Mean Value
# --------------------------------------
# 0            | 0.0200      | 0.0292
# 1            | 0.0371      | 0.0384
# 2            | 0.0428      | 0.0438
# 3            | 0.0207      | 0.0541
# 4            | 0.0954      | 0.0751
# 5            | 0.0986      | 0.1046
# 6            | 0.1539      | 0.1216
# 7            | 0.1601      | 0.1347
# 8            | 0.3109      | 0.1774
# 9            | 0.2111      | 0.2082
# 10           | 0.1609      | 0.2364
# 11           | 0.1582      | 0.2507
# 12           | 0.2238      | 0.2735
# 13           | 0.0645      | 0.2977
# 14           | 0.0660      | 0.3214
# 15           | 0.2273      | 0.3792
# 16           | 0.3100      | 0.4165
# 17           | 0.2999      | 0.4531
# 18           | 0.5078      | 0.5048
# 19           | 0.4797      | 0.5634
# 20           | 0.5783      | 0.6092
# 21           | 0.5071      | 0.6248
# 22           | 0.4328      | 0.6480
# 23           | 0.5550      | 0.6732
# ...

# %%
# seperable data and the tables

X = sonar_data.drop(columns = sonar_data.columns[60], axis = 1)
Y = sonar_data[sonar_data.columns[60]]

# %%
print(X)
print(Y)
# Out:
#      0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  ...  0.0072  0.0167  0.0180  0.0084  0.0090  0.0032
# 0    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  ...  0.0094  0.0191  0.0140  0.0049  0.0052  0.0044
# 1    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  ...  0.0180  0.0244  0.0316  0.0164  0.0095  0.0078
# 2    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  ...  0.0085  0.0073  0.0050  0.0044  0.0040  0.0117
# 3    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  ...  0.0110  0.0015  0.0072  0.0048  0.0107  0.0094
# 4    0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  ...  0.0013  0.0089  0.0057  0.0027  0.0051  0.0062
# ..      ...     ...     ...     ...     ...     ...  ...     ...     ...     ...     ...     ...     ...
# 202  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  ...  0.0033  0.0101  0.0065  0.0115  0.0193  0.0157
# 203  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  ...  0.0063  0.0063  0.0034  0.0032  0.0062  0.0067
# ...

# %%
X_train , Y_train , X_test , Y_test = train_test_split(X,Y,test_size = 0.1,stratify = Y,random_state = 1)

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (207, 60) (186, 60) (186,)

# %%
# model training -->  ogistic regression model

# %%
model = LogisticRegression()

# %%
# training the logistic regression model with the training data

Y = sonar_data.iloc[:, 60]  # Extract only the label column as a 1D Series

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()  # Create model
model.fit(X_train, Y_train)   # Train model
# Out:
# LogisticRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
# Accuracy on the training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
accuracy_score(X_train_prediction, Y_train)
# Out:
# 0.8484848484848485

# %%
# Accuracy on the training data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
accuracy_score(X_test_prediction, Y_test)
# Out:
# 0.7619047619047619

# %% [markdown]
# Making a predictive System

# %%
input_data = ()


# changing the input data to anumpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the np array as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

# %%
input_data = (0.0762, 0.0666, 0.0481, 0.0394, 0.059, 0.0649, 0.1209, 0.2467,
              0.3564, 0.4459, 0.4152, 0.3952, 0.4256, 0.4135, 0.4528, 0.5326,
              0.7306, 0.6193, 0.2032, 0.4636, 0.4148, 0.4292, 0.573, 0.5399,
              0.3161, 0.2285, 0.6995, 1, 0.7262, 0.4724, 0.5103, 0.5459, 0.2881,
              0.0981, 0.1951, 0.4181, 0.4604, 0.3217, 0.2828, 0.243, 0.1979,
              0.2444, 0.1847, 0.0841, 0.0692, 0.0528, 0.0357, 0.0085, 0.023,
              0.0046, 0.0156, 0.0031, 0.0054, 0.0105, 0.011, 0.0015, 0.0072,
              0.0048, 0.0107, 0.0094)




input_data_as_numpy_array = np.asarray(input_data)

# reshape the np array as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = model.predict(input_data_reshaped)
print(prediction)

if (prediction[0]=='R'):
  print('The object is a Rock')
else:

  print('The object is a mine')
# Out:
# ['M']
# The object is a mine
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
input_data = (0.0762, 0.0666, 0.0481, 0.0394, 0.059)  # Example tuple
converted_data = ", ".join(map(str, input_data))  # Convert to string with commas
print(converted_data)
# Out:
# 0.0762, 0.0666, 0.0481, 0.0394, 0.059
